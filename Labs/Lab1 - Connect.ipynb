// %% [markdown]
// Open the Azure Cosmos DB Emulator and verify it is working. It can take up to 5 minutes for Cosmos DB Emulator to be ready to accept calls.
// https://localhost:8081/_explorer/index.html

// %% [markdown]
// You need to use Microsoft.Azure.Cosmos package to connect and work with Azure Cosmos DB.
// You can reference any nuget packages by using the following format.
//
// #r "nuget: Microsoft.Azure.Cosmos"
//
// You may need to reference Newtonsoft.Json package manually if you receive any error from the Microsoft.Azure.Cosmos package.
//
// You need to reference Newtonsoft.Json first if you receive an error.
// #r "nuget: Newtonsoft.Json"
//
// Execute the following code to install required packages.

// %%
#r "nuget: Newtonsoft.Json"
#r "nuget: Microsoft.Azure.Cosmos"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Azure.Cosmos, 3.51.0</span></li><li><span>Newtonsoft.Json, 13.0.3</span></li></ul></div></div>

// %% [markdown]
// After successful installation, reference the Microsoft.Azure.Cosmos
// using Microsoft.Azure.Cosmos;

// %%
using Microsoft.Azure.Cosmos;

// %% [markdown]
// Open the Azure Cosmos DB Emulator and find the connection strings.
//
// Declare an object named client using the  CosmosClient constructor.
//
//
// Copy connection string from the Azure Cosmos DB Emulator and paste it to initialize the CosmosClient.
//
// CosmosClientOptions parameter is optional and it has many useful options. Take a look at CosmosClient file under Study directory to learn more about its members.
//
// Display() function is a great VsCode Polygot function. It displays all the properties/values of an object in a readable format.
//
// Use Display() function to explore the options of client object after initialization.

// %%
// Create a new CosmosClient object

// %% [markdown]
// You can use 2. CreateDB file in Study for help for the following questions.
//
// 1. Create a new database named "Stackoverflow" by using the CreateDatabaseIfNotExistsAsync function.
//
// 2. Load the database you created by using the GetDatabase function.
//
// 3. Create a new container named "Posts" under the database you just created. Use the "/OwnerUserId" property as partition key
//
// Don't forget everything is case-sensitive!!
//
// 4. Explore the new database and container properties by using Display() function.

// %%
// Create a new database named StackOverflow

//Create a new container named Posts. Use the /OwnerUserId property as partition key

// %% [markdown]
// Open The Azure Cosmos DB Emulator and verify database and container is created
