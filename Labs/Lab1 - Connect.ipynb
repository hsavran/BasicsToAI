// %% [markdown]
// Launch the Azure Cosmos DB Emulator and confirm it is operational. It may take up to 5 minutes for the Cosmos DB Emulator to be ready to accept requests.
// https://localhost:8081/_explorer/index.html

// %% [markdown]
// You need to use `Microsoft.Azure.Cosmos` package for connecting to and working with Azure Cosmos DB.
// You can reference any NuGet packages by using the following format.
//
// `#r "nuget: Microsoft.Azure.Cosmos"`
//
// You may need to reference the `Newtonsoft.Json` package manually if you receive any error from Microsoft.Azure.Cosmos package.
//
// You need to reference Newtonsoft.Json first if you receive an error.
// #r "nuget: Newtonsoft.Json"
//
// Execute the following code to install the required packages.

// %%
#r "nuget: Newtonsoft.Json"
#r "nuget: Microsoft.Azure.Cosmos"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Azure.Cosmos, 3.51.0</span></li><li><span>Newtonsoft.Json, 13.0.3</span></li></ul></div></div>

// %% [markdown]
// After completing the installation successfully, make sure to reference the Microsoft.Azure.Cosmos library.
//
// Execute the following code.

// %%
using Microsoft.Azure.Cosmos;

// %% [markdown]
// 1. Open the Azure Cosmos DB Emulator and locate the connection strings.
//
// 2. Declare an object named `client` using the `CosmosClient` constructor.
//
// 3. Copy the connection string from the Azure Cosmos DB Emulator and paste it to initialize the `CosmosClient`.
//
// 4. The `CosmosClientOptions` parameter is optional and comes with many useful options. Refer to the `CosmosClient` file in the Study directory to learn more about its available members. You don't need to use it for this example.
//
// 5. The `Display()` function is a great feature in VS Code that shows all the properties and values of an object in a readable format.
//
// 6. Use the `Display()` function to explore the options of the `client` object after initialization.

// %%
// Create a new CosmosClient object and use Display() to show it

// %% [markdown]
// You can refer to the `"2. CreateDB"` file in the Study section for assistance with the following tasks:
//
// use the client object to complete the following tasks.
//
// 1. Create a new database named `"Stackoverflow"` using the `CreateDatabaseIfNotExistsAsync` function.
//
// 2. Load the database you just created by utilizing the `GetDatabase` function.
//
// 3. Create a new container named `"Posts"` within the database you created. Use the `"/OwnerUserId"` property as the partition key.
//
// Please remember that everything is case-sensitive!
//
// 4. Explore the properties of the new database and container by using the `Display()` function.

// %%
// Create a new database named StackOverflow

// Load the database you just created to create a container in it

//Create a new container named Posts. Use the /OwnerUserId property as partition key

// %% [markdown]
// Open the Azure Cosmos DB Emulator and verify that the database and container have been created successfully.
